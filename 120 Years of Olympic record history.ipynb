# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
sns.set_style('darkgrid')

# %%
df1 = pd.read_csv(r"C:\Users\Sinha Rahul\Downloads\athlete_events.csv (1).zip")
df2 = pd.read_csv(r"C:\Users\Sinha Rahul\Downloads\noc_regions.csv")

# %%
df1.sample(5)
# Out:
#            ID                               Name Sex   Age  Height  Weight  \
# 140906  70738  Robert Cambridge "Bob" Livingston   M  23.0     NaN     NaN
# 187009  94009                   Vratislav Petrek   M  26.0     NaN     NaN
# 152850  76709            Marcus Laborne Mattioli   M  19.0   181.0    75.0
# 109937  55587                      Jon Myong-Hui   F  21.0   175.0    65.0
# 96437   48829                 Robert David Hirst   M  20.0     NaN     NaN
#
#                           Team  NOC        Games  Year  Season         City  \
# 140906           United States  USA  1932 Winter  1932  Winter  Lake Placid
# 187009          Czechoslovakia  TCH  1936 Summer  1936  Summer       Berlin
# 152850                  Brazil  BRA  1980 Summer  1980  Summer       Moskva
# 109937             North Korea  PRK  2008 Summer  2008  Summer      Beijing
# 96437   British Virgin Islands  IVB  1992 Summer  1992  Summer    Barcelona
#
# ...

# %%
df2.sample(5)
# Out:
#      NOC      region notes
# 40   CHI       Chile   NaN
# 60   EGY       Egypt   NaN
# 121  LTU   Lithuania   NaN
# 217  UZB  Uzbekistan   NaN
# 108  KIR    Kiribati   NaN

# %% [markdown]
# # Joins the Dataframes

# %%
df = df1.merge(df2 , how ='left', on = 'NOC')
df.sample(5)
# Out:
#             ID                           Name Sex   Age  Height  Weight  \
# 151957   76260                    Jozef Massy   M  33.0     NaN     NaN
# 219447  110231                  Frank Siebeck   M  23.0   189.0    78.0
# 31302    16092                Brodie Buckland   M  28.0   196.0    98.0
# 231815  116294  Mikhail Mikhaylovich Sukharev   M  19.0   188.0    81.0
# 153701   77136                Marcos Mazzaron   M  20.0   175.0    62.0
#
#                 Team  NOC        Games  Year  Season         City      Sport  \
# 151957       Belgium  BEL  1948 Summer  1948  Summer       London   Canoeing
# 219447  East Germany  GDR  1972 Summer  1972  Summer       Munich  Athletics
# 31302      Australia  AUS  2012 Summer  2012  Summer       London     Rowing
# 231815  Soviet Union  URS  1972 Summer  1972  Summer       Munich   Swimming
# 153701        Brazil  BRA  1984 Summer  1984  Summer  Los Angeles    Cycling
#
# ...

# %% [markdown]
# # find out of size of data

# %%
df.shape
# Out:
# (271116, 17)

# %% [markdown]
# # statistical

# %%
df.describe()
# Out:
#                   ID            Age         Height         Weight  \
# count  271116.000000  261642.000000  210945.000000  208241.000000
# mean    68248.954396      25.556898     175.338970      70.702393
# std     39022.286345       6.393561      10.518462      14.348020
# min         1.000000      10.000000     127.000000      25.000000
# 25%     34643.000000      21.000000     168.000000      60.000000
# 50%     68205.000000      24.000000     175.000000      70.000000
# 75%    102097.250000      28.000000     183.000000      79.000000
# max    135571.000000      97.000000     226.000000     214.000000
#
#                 Year
# count  271116.000000
# mean     1978.378480
# std        29.877632
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %% [markdown]
# # check data type

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 271116 entries, 0 to 271115
# Data columns (total 17 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
#  15  region  270746 non-null  object
#  16  notes   5039 non-null    object
# dtypes: float64(3), int64(2), object(12)
# memory usage: 37.2+ MB

# %%
df.memory_usage()
# Out:
# Index     2168928
# ID        2168928
# Name      2168928
# Sex       2168928
# Age       2168928
# Height    2168928
# Weight    2168928
# Team      2168928
# NOC       2168928
# Games     2168928
# Year      2168928
# Season    2168928
# City      2168928
# Sport     2168928
# Event     2168928
# Medal     2168928
# region    2168928
# notes     2168928
# dtype: int64

# %% [markdown]
# # unirrelevant columns

# %%
df = df.drop(columns = "notes", axis = 0)

# %% [markdown]
# # Check the dublicate data and drop them

# %%
 df.isnull().sum()
# Out:
# ID             0
# Name           0
# Sex            0
# Age         9474
# Height     60171
# Weight     62875
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     231333
# region       370
# dtype: int64

# %%
plt.figure(figsize=(17,8))
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # check duplicate data

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 271111    False
# 271112    False
# 271113    False
# 271114    False
# 271115    False
# Length: 271116, dtype: bool

# %%
df[df.duplicated()]
# Out:
#             ID                                 Name Sex   Age  Height  Weight  \
# 1252       704                   Dsir Antoine Acket   M  27.0     NaN     NaN
# 4282      2449               William Truman Aldrich   M  48.0     NaN     NaN
# 4283      2449               William Truman Aldrich   M  48.0     NaN     NaN
# 4862      2777               Hermann Reinhard Alker   M  43.0     NaN     NaN
# 4864      2777               Hermann Reinhard Alker   M  43.0     NaN     NaN
# ...        ...                                  ...  ..   ...     ...     ...
# 269994  135072  Anna Katrina Zinkeisen (-Heseltine)   F  46.0     NaN     NaN
# 269995  135072  Anna Katrina Zinkeisen (-Heseltine)   F  46.0     NaN     NaN
# 269997  135072  Anna Katrina Zinkeisen (-Heseltine)   F  46.0     NaN     NaN
# 269999  135073   Doris Clare Zinkeisen (-Johnstone)   F  49.0     NaN     NaN
# 270200  135173                     Henri Achille Zo   M  58.0     NaN     NaN
#
# ...

# %%
len(df[df.duplicated()])
# Out:
# 1385

# %%
df.drop_duplicates()
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
df.duplicated().sum()
# Out:
# 1385

# %% [markdown]
# # check null value

# %%
df[['Age','Height','Weight']] = df[['Age','Height','Weight']].fillna(df[['Age','Height','Weight']].mean())

df.Medal = df.Medal.fillna('None')

df.Age = df.Age.astype(int)

# %%
df
# Out:
#             ID                      Name Sex  Age     Height     Weight  \
# 0            1                 A Dijiang   M   24  180.00000  80.000000
# 1            2                  A Lamusi   M   23  170.00000  60.000000
# 2            3       Gunnar Nielsen Aaby   M   24  175.33897  70.702393
# 3            4      Edgar Lindenau Aabye   M   34  175.33897  70.702393
# 4            5  Christine Jacoba Aaftink   F   21  185.00000  82.000000
# ...        ...                       ...  ..  ...        ...        ...
# 271111  135569                Andrzej ya   M   29  179.00000  89.000000
# 271112  135570                  Piotr ya   M   27  176.00000  59.000000
# 271113  135570                  Piotr ya   M   27  176.00000  59.000000
# 271114  135571        Tomasz Ireneusz ya   M   30  185.00000  96.000000
# 271115  135571        Tomasz Ireneusz ya   M   34  185.00000  96.000000
#
#                   Team  NOC        Games  Year  Season            City  \
# ...

# %%
df.isnull().sum().sum()
# Out:
# 370

# %%
plt.figure(figsize=(17,8))
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.shape
# Out:
# (271116, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 271116 entries, 0 to 271115
# Data columns (total 16 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     271116 non-null  int32
#  4   Height  271116 non-null  float64
#  5   Weight  271116 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   271116 non-null  object
#  15  region  270746 non-null  object
# dtypes: float64(2), int32(1), int64(2), object(11)
# memory usage: 34.1+ MB

# %% [markdown]
# # Exploratory Analysis and Visualization

# %% [markdown]
# # Top countries participating in Olympics

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal', 'region'],
#       dtype='object')

# %%
df["Team"].nunique()
# Out:
# 1184

# %%
top_country = df["Team"].value_counts().sort_values(ascending=False).head(10)
top_country
# Out:
# United States    17847
# France           11988
# Great Britain    11404
# Italy            10260
# Germany           9326
# Canada            9279
# Japan             8289
# Sweden            8052
# Australia         7513
# Hungary           6547
# Name: Team, dtype: int64

# %%
plt.figure(figsize=(12,6))
plt.xticks(rotation=75,fontsize=20)
plt.title('Overall Participation Countrywise',fontsize=20)
barplot = sns.barplot(x=top_country.index, y=top_country)
for bars in barplot.containers:
    barplot.bar_label(bars,fontsize = 20)

# %% [markdown]
# # USA has historically won maximum no of medals

# %% [markdown]
# # Age Distribution

# %%
df["Age"].value_counts()
# Out:
# 25    29181
# 23    21875
# 24    21720
# 22    20814
# 21    19164
#       ...
# 77        2
# 84        1
# 10        1
# 96        1
# 97        1
# Name: Age, Length: 74, dtype: int64

# %%
plt.figure(figsize=(12, 6))
plt.xlabel('Age')
plt.ylabel('Number of Participant')
plt.hist(df["Age"], color= "r")
plt.xticks(rotation=75,fontsize=15)
plt.show()

# %% [markdown]
# # Gender Distribution

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal', 'region'],
#       dtype='object')

# %%
df["Sex"].value_counts()
# Out:
# M    196594
# F     74522
# Name: Sex, dtype: int64

# %% [markdown]
# # To get the percentage

# %%
plt.figure(figsize=(12,6))
plt.title('Gender Distribution')
plt.pie(df["Sex"].value_counts(), labels=df["Sex"].value_counts().keys(), autopct='%1.1f%%', startangle=180);

# %% [markdown]
# # how many team are there participate in this 140 year olympic historty

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal', 'region'],
#       dtype='object')

# %%
df["Team"].nunique()
# Out:
# 1184

# %% [markdown]
# # how many sports are there participate in this 140 year olympic historty

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal', 'region'],
#       dtype='object')

# %%
df["Sport"].unique()
# Out:
# array(['Basketball', 'Judo', 'Football', 'Tug-Of-War', 'Speed Skating',
#        'Cross Country Skiing', 'Athletics', 'Ice Hockey', 'Swimming',
#        'Badminton', 'Sailing', 'Biathlon', 'Gymnastics',
#        'Art Competitions', 'Alpine Skiing', 'Handball', 'Weightlifting',
#        'Wrestling', 'Luge', 'Water Polo', 'Hockey', 'Rowing', 'Bobsleigh',
#        'Fencing', 'Equestrianism', 'Shooting', 'Boxing', 'Taekwondo',
#        'Cycling', 'Diving', 'Canoeing', 'Tennis', 'Modern Pentathlon',
#        'Figure Skating', 'Golf', 'Softball', 'Archery', 'Volleyball',
#        'Synchronized Swimming', 'Table Tennis', 'Nordic Combined',
#        'Baseball', 'Rhythmic Gymnastics', 'Freestyle Skiing',
#        'Rugby Sevens', 'Trampolining', 'Beach Volleyball', 'Triathlon',
#        'Ski Jumping', 'Curling', 'Snowboarding', 'Rugby',
#        'Short Track Speed Skating', 'Skeleton', 'Lacrosse', 'Polo',
#        'Cricket', 'Racquets', 'Motorboating', 'Military Ski Patrol',
# ...

# %%
df["Sport"].nunique()
# Out:
# 66

# %% [markdown]
# # how many season are there participate in this 140 year olympic historty

# %%
df["Season"].unique()
# Out:
# array(['Summer', 'Winter'], dtype=object)

# %% [markdown]
# # how many games are there participate in this 140 year olympic historty

# %%
df["Games"].unique()
# Out:
# array(['1992 Summer', '2012 Summer', '1920 Summer', '1900 Summer',
#        '1988 Winter', '1992 Winter', '1994 Winter', '1932 Summer',
#        '2002 Winter', '1952 Summer', '1980 Winter', '2000 Summer',
#        '1996 Summer', '1912 Summer', '1924 Summer', '2014 Winter',
#        '1948 Summer', '1998 Winter', '2006 Winter', '2008 Summer',
#        '2016 Summer', '2004 Summer', '1960 Winter', '1964 Winter',
#        '1984 Winter', '1984 Summer', '1968 Summer', '1972 Summer',
#        '1988 Summer', '1936 Summer', '1952 Winter', '1956 Winter',
#        '1956 Summer', '1960 Summer', '1928 Summer', '1976 Summer',
#        '1980 Summer', '1964 Summer', '2010 Winter', '1968 Winter',
#        '1906 Summer', '1972 Winter', '1976 Winter', '1924 Winter',
#        '1904 Summer', '1928 Winter', '1908 Summer', '1948 Winter',
#        '1932 Winter', '1936 Winter', '1896 Summer'], dtype=object)

# %% [markdown]
# # Young and old athletes detected according to the average age.

# %%
avarge_age = df["Age"].mean()
avarge_age
# Out:
# 25.537437849481403

# %%
dff = df["Age"].unique()
dff
# Out:
# array([24, 23, 34, 21, 25, 27, 31, 33, 18, 26, 22, 30, 32, 28, 54, 20, 17,
#        43, 47, 29, 41, 45, 49, 53, 57, 19, 38, 35, 16, 37, 15, 42, 46, 40,
#        36, 14, 39, 48, 52, 44, 55, 50, 71, 63, 51, 58, 13, 60, 75, 65, 56,
#        64, 68, 84, 12, 72, 59, 61, 70, 74, 62, 67, 69, 73, 66, 11, 76, 88,
#        96, 80, 10, 81, 77, 97])

# %%
df["Age_Level"]=["Old" if item>avarge_age else "Young" for item in df["Age"]]

# %%
df.loc[:10,["Name","Age","Age_Level"]]
# Out:
#                         Name  Age Age_Level
# 0                  A Dijiang   24     Young
# 1                   A Lamusi   23     Young
# 2        Gunnar Nielsen Aaby   24     Young
# 3       Edgar Lindenau Aabye   34       Old
# 4   Christine Jacoba Aaftink   21     Young
# 5   Christine Jacoba Aaftink   21     Young
# 6   Christine Jacoba Aaftink   25     Young
# 7   Christine Jacoba Aaftink   25     Young
# 8   Christine Jacoba Aaftink   27       Old
# 9   Christine Jacoba Aaftink   27       Old
# 10           Per Knut Aaland   31       Old

# %% [markdown]
# # gold medal winners who are less than 18 years of age

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal', 'region',
#        'Age_Level'],
#       dtype='object')

# %%
df["Medal"].unique()
# Out:
# array(['None', 'Gold', 'Bronze', 'Silver'], dtype=object)

# %%
df["Medal"].value_counts()
# Out:
# None      231333
# Gold       13372
# Bronze     13295
# Silver     13116
# Name: Medal, dtype: int64

# %%
((df["Age"]<18) & (df["Medal"]=="Gold"))
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 271111    False
# 271112    False
# 271113    False
# 271114    False
# 271115    False
# Length: 271116, dtype: bool

# %%
df[((df["Age"]<18) & (df["Medal"]=="Gold"))].head(1)
# Out:
#       ID                         Name Sex  Age     Height     Weight  \
# 710  404  Louis Grenville "Lou" Abell   M   15  175.33897  70.702393
#
#                  Team  NOC        Games  Year  Season   City   Sport  \
# 710  Vesper Boat Club  USA  1900 Summer  1900  Summer  Paris  Rowing
#
#                          Event Medal region Age_Level
# 710  Rowing Men's Coxed Eights  Gold    USA     Young

# %%
len(df[((df["Age"]<18) & (df["Medal"]=="Gold"))])
# Out:
# 424

# %% [markdown]
# # silver medal winners who are less than 18 years of age

# %%
((df["Age"]<18) & (df["Medal"]=="Silver"))
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 271111    False
# 271112    False
# 271113    False
# 271114    False
# 271115    False
# Length: 271116, dtype: bool

# %%
df[((df["Age"]<18) & (df["Medal"]=="Silver"))].head(1)
# Out:
#         ID           Name Sex  Age  Height  Weight     Team  NOC        Games  \
# 2587  1449  Thomas Ahrens   M   16   163.0    50.0  Germany  GER  1964 Summer
#
#       Year  Season   City   Sport                      Event   Medal   region  \
# 2587  1964  Summer  Tokyo  Rowing  Rowing Men's Coxed Eights  Silver  Germany
#
#      Age_Level
# 2587     Young

# %%
len(df[((df["Age"]<18) & (df["Medal"]=="Silver"))])
# Out:
# 400

# %% [markdown]
# # bronze medal winners who are less than 18 years of age

# %%
((df["Age"]<18) & (df["Medal"]=="Bronze"))
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 271111    False
# 271112    False
# 271113    False
# 271114    False
# 271115    False
# Length: 271116, dtype: bool

# %%
df[((df["Age"]<18) & (df["Medal"]=="Bronze"))].head(1)
# Out:
#       ID                     Name Sex  Age     Height     Weight  \
# 740  424  Moira Abernethy (-Ford)   F   17  175.33897  70.702393
#
#              Team  NOC        Games  Year  Season       City     Sport  \
# 740  South Africa  RSA  1956 Summer  1956  Summer  Melbourne  Swimming
#
#                                                Event   Medal        region  \
# 740  Swimming Women's 4 x 100 metres Freestyle Relay  Bronze  South Africa
#
#     Age_Level
# 740     Young

# %%
len(df[((df["Age"]<18) & (df["Medal"]=="Bronze"))])
# Out:
# 355

# %% [markdown]
# # gold medal winners who are less than 18 years to 25  of age

# %%
((df["Age"].between(18,25)) & (df["Medal"]=="Gold"))
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 271111    False
# 271112    False
# 271113    False
# 271114    False
# 271115    False
# Length: 271116, dtype: bool

# %%
df[((df["Age"].between(18,25)) & (df["Medal"]=="Gold"))].head(1)
# Out:
#     ID                Name Sex  Age  Height  Weight    Team  NOC        Games  \
# 60  20  Kjetil Andr Aamodt   M   20   176.0    85.0  Norway  NOR  1992 Winter
#
#     Year  Season         City          Sport                        Event  \
# 60  1992  Winter  Albertville  Alpine Skiing  Alpine Skiing Men's Super G
#
#    Medal  region Age_Level
# 60  Gold  Norway     Young

# %%
len(df[((df["Age"].between(18,25)) & (df["Medal"]=="Gold"))])
# Out:
# 6909

# %%
len(df[((df["Age"].between(18,25)) & (df["Medal"]=="Silver"))])
# Out:
# 6724

# %%
len(df[((df["Age"].between(18,25)) & (df["Medal"]=="Bronze"))])
# Out:
# 6983

# %%
len(df[((df["Age"]>=50) & (df["Medal"]=="Gold"))])
# Out:
# 77

# %%
len(df[((df["Age"]>=50) & (df["Medal"]=="Bronze"))])
# Out:
# 72

# %%
len(df[((df["Age"]>=50) & (df["Medal"]=="Silver"))])
# Out:
# 87

# %% [markdown]
# # check the female participants of the years 1896 to 2016

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal', 'region',
#        'Age_Level'],
#       dtype='object')

# %%
df3 = df.sort_values(by = "Year")
df3.head(1)
# Out:
#             ID                         Name Sex  Age     Height     Weight  \
# 214333  107607  Fritz Richard Gustav Schuft   M   19  175.33897  70.702393
#
#            Team  NOC        Games  Year  Season    City       Sport  \
# 214333  Germany  GER  1896 Summer  1896  Summer  Athina  Gymnastics
#
#                                    Event Medal   region Age_Level
# 214333  Gymnastics Men's Pommelled Horse  None  Germany     Young

# %%
df3["Year"].unique()
# Out:
# array([1896, 1900, 1904, 1906, 1908, 1912, 1920, 1924, 1928, 1932, 1936,
#        1948, 1952, 1956, 1960, 1964, 1968, 1972, 1976, 1980, 1984, 1988,
#        1992, 1994, 1996, 1998, 2000, 2002, 2004, 2006, 2008, 2010, 2012,
#        2014, 2016], dtype=int64)

# %%
df["Sex"]=="F"
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4          True
#           ...
# 271111    False
# 271112    False
# 271113    False
# 271114    False
# 271115    False
# Name: Sex, Length: 271116, dtype: bool

# %%
female_participated = df[df["Sex"]=="F"][["Year","Sex"]]
female_participated
# Out:
#         Year Sex
# 4       1988   F
# 5       1988   F
# 6       1992   F
# 7       1992   F
# 8       1994   F
# ...      ...  ..
# 271080  1964   F
# 271099  2004   F
# 271102  2000   F
# 271103  2004   F
# 271110  2016   F
#
# [74522 rows x 2 columns]

# %%
female_participated = female_participated.groupby(["Year"]).count()

# %%
female_participated.sort_values("Sex", ascending=False).head()
# Out:
#        Sex
# Year
# 2016  6223
# 2008  5816
# 2012  5815
# 2004  5546
# 2000  5431

# %%
female_participated.sort_values("Sex", ascending=True).head()
# Out:
#       Sex
# Year
# 1906   11
# 1904   16
# 1900   33
# 1908   47
# 1912   87

# %%
plt.figure(figsize=(12,6))
sns.lineplot(
    data=female_participated, x="Year", y="Sex",  err_style="bars", ci=68
)
plt.title('female Participated in year wise', fontsize=20)
plt.show()

# %% [markdown]
# # check the male participants of the years 1896 to 2016

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal', 'region',
#        'Age_Level'],
#       dtype='object')

# %%
df3 = df.sort_values(by = "Year")
df3.head(1)
# Out:
#             ID                         Name Sex  Age     Height     Weight  \
# 214333  107607  Fritz Richard Gustav Schuft   M   19  175.33897  70.702393
#
#            Team  NOC        Games  Year  Season    City       Sport  \
# 214333  Germany  GER  1896 Summer  1896  Summer  Athina  Gymnastics
#
#                                    Event Medal   region Age_Level
# 214333  Gymnastics Men's Pommelled Horse  None  Germany     Young

# %%
df3["Year"].unique()
# Out:
# array([1896, 1900, 1904, 1906, 1908, 1912, 1920, 1924, 1928, 1932, 1936,
#        1948, 1952, 1956, 1960, 1964, 1968, 1972, 1976, 1980, 1984, 1988,
#        1992, 1994, 1996, 1998, 2000, 2002, 2004, 2006, 2008, 2010, 2012,
#        2014, 2016], dtype=int64)

# %%
df["Sex"]=="M"
# Out:
# 0          True
# 1          True
# 2          True
# 3          True
# 4         False
#           ...
# 271111     True
# 271112     True
# 271113     True
# 271114     True
# 271115     True
# Name: Sex, Length: 271116, dtype: bool

# %%
Male_participated = df[df["Sex"]=="M"][["Year","Sex"]]
Male_participated
# Out:
#         Year Sex
# 0       1992   M
# 1       2012   M
# 2       1920   M
# 3       1900   M
# 10      1992   M
# ...      ...  ..
# 271111  1976   M
# 271112  2014   M
# 271113  2014   M
# 271114  1998   M
# 271115  2002   M
#
# [196594 rows x 2 columns]

# %%
Male_participated = Male_participated.groupby(["Year"]).count()

# %%
Male_participated
# Out:
#         Sex
# Year
# 1896    380
# 1900   1903
# 1904   1285
# 1906   1722
# 1908   3054
# 1912   3953
# 1920   4158
# 1924   5432
# 1928   5137
# 1932   2952
# 1936   6852
# 1948   6719
# 1952   7676
# 1956   5295
# 1960   7505
# 1964   7728
# 1968   8286
# 1972   9351
# 1976   7896
# 1980   6751
# 1984   8605
# 1988  10453
# 1992  11235
# 1994   2055
# 1996   8772
# 1998   2221
# 2000   8390
# 2002   2527
# 2004   7897
# 2006   2625
# 2008   7786
# 2010   2555
# 2012   7105
# 2014   2868
# 2016   7465

# %%
Male_participated.sort_values("Sex", ascending=False).head()
# Out:
#         Sex
# Year
# 1992  11235
# 1988  10453
# 1972   9351
# 1996   8772
# 1984   8605

# %%
Male_participated.sort_values("Sex", ascending=True).head()
# Out:
#        Sex
# Year
# 1896   380
# 1904  1285
# 1906  1722
# 1900  1903
# 1994  2055

# %%
plt.figure(figsize=(12,6))

sns.lineplot(
    data=Male_participated, x="Year", y="Sex",  err_style="bars", ci=68)
plt.title('Male Participated in year wise', fontsize=20)
plt.show()

# %% [markdown]
# # Participants across seasons

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal', 'region',
#        'Age_Level'],
#       dtype='object')

# %%
df["Season"].value_counts()
# Out:
# Summer    222552
# Winter     48564
# Name: Season, dtype: int64

# %%
plt.figure(figsize=(12,6))
plt.title('Participants across seasons', fontsize=20)
plt.pie(df["Season"].value_counts(), labels=df["Season"].value_counts().keys(), autopct='%1.1f%%', startangle=180,radius=1,
       textprops = {"fontsize":20})
plt.show()

# %% [markdown]
# # check the male participants of the years 1896 to 2016 in winter season

# %%
(df["Sex"]=="M") & (df["Season"]=="Winter")
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 271111     True
# 271112     True
# 271113     True
# 271114     True
# 271115     True
# Length: 271116, dtype: bool

# %%
df[(df["Sex"]=="M") & (df["Season"]=="Winter")].head(1)
# Out:
#     ID             Name Sex  Age  Height  Weight           Team  NOC  \
# 10   6  Per Knut Aaland   M   31   188.0    75.0  United States  USA
#
#           Games  Year  Season         City                 Sport  \
# 10  1992 Winter  1992  Winter  Albertville  Cross Country Skiing
#
#                                        Event Medal region Age_Level
# 10  Cross Country Skiing Men's 10 kilometres  None    USA       Old

# %%
len(df[(df["Sex"]=="M") & (df["Season"]=="Winter")])
# Out:
# 33485

# %%
winter_participated_Male = df[(df["Sex"]=="M") & (df["Season"]=="Winter")][["Year","Sex"]]

# %%
winter_participated_Male
# Out:
#         Year Sex
# 10      1992   M
# 11      1992   M
# 12      1992   M
# 13      1992   M
# 14      1994   M
# ...      ...  ..
# 271111  1976   M
# 271112  2014   M
# 271113  2014   M
# 271114  1998   M
# 271115  2002   M
#
# [33485 rows x 2 columns]

# %%
winter_participated_Male = winter_participated_Male.groupby("Year").count()

# %%
winter_participated_Male
# Out:
#        Sex
# Year
# 1924   443
# 1928   549
# 1932   330
# 1936   814
# 1948   942
# 1952   903
# 1956  1061
# 1960   821
# 1964  1374
# 1968  1475
# 1972  1240
# 1976  1427
# 1980  1316
# 1984  1598
# 1988  1959
# 1992  2382
# 1994  2055
# 1998  2221
# 2002  2527
# 2006  2625
# 2010  2555
# 2014  2868

# %%
plt.figure(figsize=(12,6))

sns.lineplot(
    data=winter_participated_Male, x="Year", y="Sex",  err_style="bars", ci=68)
plt.title('winter_participated_Male in year wise', fontsize=20)
plt.show()

# %% [markdown]
# # check the female participants of the years 1896 to 2016 in winter season

# %%
(df["Sex"]=="F") & (df["Season"]=="Winter")
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4          True
#           ...
# 271111    False
# 271112    False
# 271113    False
# 271114    False
# 271115    False
# Length: 271116, dtype: bool

# %%
df[(df["Sex"]=="F") & (df["Season"]=="Winter")].head(1)
# Out:
#    ID                      Name Sex  Age  Height  Weight         Team  NOC  \
# 4   5  Christine Jacoba Aaftink   F   21   185.0    82.0  Netherlands  NED
#
#          Games  Year  Season     City          Sport  \
# 4  1988 Winter  1988  Winter  Calgary  Speed Skating
#
#                               Event Medal       region Age_Level
# 4  Speed Skating Women's 500 metres  None  Netherlands     Young

# %%
len(df[(df["Sex"]=="F") & (df["Season"]=="Winter")])
# Out:
# 15079

# %%
winter_participated_female = df[(df["Sex"]=="F") & (df["Season"]=="Winter")][["Year","Sex"]]

# %%
winter_participated_female
# Out:
#         Year Sex
# 4       1988   F
# 5       1988   F
# 6       1992   F
# 7       1992   F
# 8       1994   F
# ...      ...  ..
# 271061  2002   F
# 271062  2002   F
# 271063  2002   F
# 271064  2002   F
# 271065  2002   F
#
# [15079 rows x 2 columns]

# %%
winter_participated_female = winter_participated_female.groupby("Year").count()

# %%
winter_participated_female
# Out:
#        Sex
# Year
# 1924    17
# 1928    33
# 1932    22
# 1936    81
# 1948   133
# 1952   185
# 1956   246
# 1960   295
# 1964   404
# 1968   416
# 1972   415
# 1976   434
# 1980   430
# 1984   536
# 1988   680
# 1992  1054
# 1994  1105
# 1998  1384
# 2002  1582
# 2006  1757
# 2010  1847
# 2014  2023

# %%
plt.figure(figsize=(12,6))

sns.lineplot(
    data=winter_participated_female, x="Year", y="Sex",  err_style="bars", ci=68)
plt.title('winter_participated_female in year wise', fontsize=20)
plt.show()

# %% [markdown]
# # check the male participants of the years 1896 to 2016 in summer season

# %%
(df["Sex"]=="M") & (df["Season"]=="Summer")
# Out:
# 0          True
# 1          True
# 2          True
# 3          True
# 4         False
#           ...
# 271111    False
# 271112    False
# 271113    False
# 271114    False
# 271115    False
# Length: 271116, dtype: bool

# %%
df[(df["Sex"]=="M") & (df["Season"]=="Summer")].head(1)
# Out:
#    ID       Name Sex  Age  Height  Weight   Team  NOC        Games  Year  \
# 0   1  A Dijiang   M   24   180.0    80.0  China  CHN  1992 Summer  1992
#
#    Season       City       Sport                        Event Medal region  \
# 0  Summer  Barcelona  Basketball  Basketball Men's Basketball  None  China
#
#   Age_Level
# 0     Young

# %%
len(df[(df["Sex"]=="M") & (df["Season"]=="Summer")])
# Out:
# 163109

# %%
summer_participated_male = df[(df["Sex"]=="M") & (df["Season"]=="Summer")][["Year","Sex"]]

# %%
summer_participated_male
# Out:
#         Year Sex
# 0       1992   M
# 1       2012   M
# 2       1920   M
# 3       1900   M
# 29      1952   M
# ...      ...  ..
# 271105  2000   M
# 271106  2004   M
# 271107  1972   M
# 271108  2000   M
# 271109  2004   M
#
# [163109 rows x 2 columns]

# %%
summer_participated_male = summer_participated_male.groupby("Year").count()

# %%
summer_participated_male
# Out:
#        Sex
# Year
# 1896   380
# 1900  1903
# 1904  1285
# 1906  1722
# 1908  3054
# 1912  3953
# 1920  4158
# 1924  4989
# 1928  4588
# 1932  2622
# 1936  6038
# 1948  5777
# 1952  6773
# 1956  4234
# 1960  6684
# 1964  6354
# 1968  6811
# 1972  8111
# 1976  6469
# 1980  5435
# 1984  7007
# 1988  8494
# 1992  8853
# 1996  8772
# 2000  8390
# 2004  7897
# 2008  7786
# 2012  7105
# 2016  7465

# %%
plt.figure(figsize=(12,6))

sns.lineplot(
    data=summer_participated_male, x="Year", y="Sex",  err_style="bars",ci=68)
plt.title('summer_participated_male in year wise', fontsize=20)
plt.show()

# %% [markdown]
# # check the female participants of the years 1896 to 2016 in summer season

# %%
(df["Sex"]=="F") & (df["Season"]=="Summer")
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 271111    False
# 271112    False
# 271113    False
# 271114    False
# 271115    False
# Length: 271116, dtype: bool

# %%
df[(df["Sex"]=="F") & (df["Season"]=="Summer")].head(1)
# Out:
#     ID                                Name Sex  Age  Height     Weight  \
# 26   8  Cornelia "Cor" Aalten (-Strannood)   F   18   168.0  70.702393
#
#            Team  NOC        Games  Year  Season         City      Sport  \
# 26  Netherlands  NED  1932 Summer  1932  Summer  Los Angeles  Athletics
#
#                            Event Medal       region Age_Level
# 26  Athletics Women's 100 metres  None  Netherlands     Young

# %%
len(df[(df["Sex"]=="F") & (df["Season"]=="Summer")])
# Out:
# 59443

# %%
summer_participated_female = df[(df["Sex"]=="F") & (df["Season"]=="Summer")][["Year","Sex"]]

# %%
summer_participated_female
# Out:
#         Year Sex
# 26      1932   F
# 27      1932   F
# 32      1996   F
# 33      2000   F
# 79      2008   F
# ...      ...  ..
# 271080  1964   F
# 271099  2004   F
# 271102  2000   F
# 271103  2004   F
# 271110  2016   F
#
# [59443 rows x 2 columns]

# %%
summer_participated_female = summer_participated_female.groupby("Year").count()

# %%
summer_participated_female
# Out:
#        Sex
# Year
# 1900    33
# 1904    16
# 1906    11
# 1908    47
# 1912    87
# 1920   134
# 1924   244
# 1928   404
# 1932   347
# 1936   468
# 1948   628
# 1952  1497
# 1956   893
# 1960  1435
# 1964  1348
# 1968  1777
# 1972  2193
# 1976  2172
# 1980  1756
# 1984  2447
# 1988  3543
# 1992  4124
# 1996  5008
# 2000  5431
# 2004  5546
# 2008  5816
# 2012  5815
# 2016  6223

# %%
plt.figure(figsize=(12,6))

sns.lineplot(
    data=summer_participated_female, x="Year", y="Sex",  err_style="bars", ci=68)
plt.title('summer_participated_female in year wise', fontsize=20)
plt.show()

# %% [markdown]
# # Which countries WON the maximum Gold Medals in last held Olympic competitions

# %%
(df["Year"]==2016) & (df["Medal"]=="Gold")
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 271111    False
# 271112    False
# 271113    False
# 271114    False
# 271115    False
# Length: 271116, dtype: bool

# %%
df[(df["Year"]==2016) & (df["Medal"]=="Gold")].head(1)
# Out:
#        ID             Name Sex  Age  Height  Weight    Team  NOC        Games  \
# 1080  608  Ahmad Abughaush   M   20   178.0    68.0  Jordan  JOR  2016 Summer
#
#       Year  Season            City      Sport                          Event  \
# 1080  2016  Summer  Rio de Janeiro  Taekwondo  Taekwondo Men's Featherweight
#
#      Medal  region Age_Level
# 1080  Gold  Jordan     Young

# %%
team = df[(df["Year"]==2016) & (df["Medal"]=="Gold")][["Team"]]

# %%
team
# Out:
#                  Team
# 1080           Jordan
# 1495    Great Britain
# 1849    United States
# 1850    United States
# 2453      Indonesia-1
# ...               ...
# 269277          China
# 269312         Russia
# 269368          China
# 269511          China
# 270281     Uzbekistan
#
# [665 rows x 1 columns]

# %%
data = team.value_counts().head(10).reset_index().rename(columns = {0:"Medal"})
data
# Out:
#             Team  Medal
# 0  United States    137
# 1  Great Britain     64
# 2         Russia     50
# 3        Germany     47
# 4          China     44
# 5         Brazil     34
# 6      Australia     23
# 7      Argentina     21
# 8         France     20
# 9          Japan     17

# %%
plt.figure(figsize=(12,6))
plt.xticks(rotation=75,fontsize=20)
plt.title("Contrywise Medals for the year 2016",fontsize=20)
barplot = sns.barplot(x="Medal", y="Team", data = data)
for bars in barplot.containers:
    barplot.bar_label(bars,fontsize = 20)

# %% [markdown]
# # which sport fetch the most gold medals in last olympic held

# %%
(df["Year"]==2016) & (df["Medal"]=="Gold")
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 271111    False
# 271112    False
# 271113    False
# 271114    False
# 271115    False
# Length: 271116, dtype: bool

# %%
df[(df["Year"]==2016) & (df["Medal"]=="Gold")].head(1)
# Out:
#        ID             Name Sex  Age  Height  Weight    Team  NOC        Games  \
# 1080  608  Ahmad Abughaush   M   20   178.0    68.0  Jordan  JOR  2016 Summer
#
#       Year  Season            City      Sport                          Event  \
# 1080  2016  Summer  Rio de Janeiro  Taekwondo  Taekwondo Men's Featherweight
#
#      Medal  region Age_Level
# 1080  Gold  Jordan     Young

# %%
sports = df[(df["Year"]==2016) & (df["Medal"]=="Gold")][["Sport"]]

# %%
sports
# Out:
#              Sport
# 1080     Taekwondo
# 1495        Boxing
# 1849      Swimming
# 1850      Swimming
# 2453     Badminton
# ...            ...
# 269277   Taekwondo
# 269312    Handball
# 269368     Cycling
# 269511  Volleyball
# 270281      Boxing
#
# [665 rows x 1 columns]

# %%
data1 = sports.value_counts().head(10).reset_index().rename(columns = {0:"Medal"})
data1
# Out:
#           Sport  Medal
# 0      Swimming     71
# 1     Athletics     66
# 2        Rowing     48
# 3      Football     35
# 4        Hockey     34
# 5      Handball     29
# 6      Canoeing     27
# 7       Cycling     27
# 8    Water Polo     26
# 9  Rugby Sevens     25

# %%
plt.figure(figsize=(19,8))
barplot = sns.barplot(x = "Sport",y = "Medal", data = data1)
plt.xlabel("Sport",fontsize=20)
plt.ylabel("Medal",fontsize=20)
plt.xticks(rotation=75,fontsize=20)
plt.yticks(rotation=75,fontsize=20)
for bars in barplot.containers:
    barplot.bar_label(bars,fontsize = 20)
plt.title("sportwise Medals for the year 2016",fontsize=20)
plt.show()

# %%
sports = df[(df["Year"]==2016) & (df["Medal"]=="Gold")][["Sport", "Team"]]

# %%
sports.value_counts().head(10).reset_index().rename(columns = {0:"Medal"})
# Out:
#         Sport           Team  Medal
# 0    Swimming  United States     48
# 1   Athletics  United States     27
# 2  Basketball  United States     24
# 3    Football        Germany     18
# 4      Hockey      Argentina     18
# 5    Football         Brazil     17
# 6      Hockey  Great Britain     16
# 7      Rowing  Great Britain     15
# 8    Handball         Russia     15
# 9     Cycling  Great Britain     14

# %% [markdown]
# # sports and event across winter and summer Olympics

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal', 'region',
#        'Age_Level'],
#       dtype='object')

# %%
DF = df[df["Season"] == "Summer"]
DF.head(1)
# Out:
#    ID       Name Sex  Age  Height  Weight   Team  NOC        Games  Year  \
# 0   1  A Dijiang   M   24   180.0    80.0  China  CHN  1992 Summer  1992
#
#    Season       City       Sport                        Event Medal region  \
# 0  Summer  Barcelona  Basketball  Basketball Men's Basketball  None  China
#
#   Age_Level
# 0     Young

# %%
DF["Sport"].nunique()
# Out:
# 52

# %%
df["Event"].nunique()
# Out:
# 765

# %%
DF1 = df[df["Season"]=="Winter"]
DF1.head()
# Out:
#    ID                      Name Sex  Age  Height  Weight         Team  NOC  \
# 4   5  Christine Jacoba Aaftink   F   21   185.0    82.0  Netherlands  NED
# 5   5  Christine Jacoba Aaftink   F   21   185.0    82.0  Netherlands  NED
# 6   5  Christine Jacoba Aaftink   F   25   185.0    82.0  Netherlands  NED
# 7   5  Christine Jacoba Aaftink   F   25   185.0    82.0  Netherlands  NED
# 8   5  Christine Jacoba Aaftink   F   27   185.0    82.0  Netherlands  NED
#
#          Games  Year  Season         City          Sport  \
# 4  1988 Winter  1988  Winter      Calgary  Speed Skating
# 5  1988 Winter  1988  Winter      Calgary  Speed Skating
# 6  1992 Winter  1992  Winter  Albertville  Speed Skating
# 7  1992 Winter  1992  Winter  Albertville  Speed Skating
# 8  1994 Winter  1994  Winter  Lillehammer  Speed Skating
#
#                                 Event Medal       region Age_Level
# 4    Speed Skating Women's 500 metres  None  Netherlands     Young
# ...

# %%
DF1["Sport"].nunique()
# Out:
# 17

# %%
DF1["Event"].nunique()
# Out:
# 119

# %% [markdown]
# # countries winning maximum medals per year

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal', 'region',
#        'Age_Level'],
#       dtype='object')

# %%
data2 = df["Medal"]!="None"

# %%
data2 = df[df["Medal"]!="None"]

# %%
data2
# Out:
#             ID                                 Name Sex  Age     Height  \
# 3            4                 Edgar Lindenau Aabye   M   34  175.33897
# 37          15                 Arvo Ossian Aaltonen   M   30  175.33897
# 38          15                 Arvo Ossian Aaltonen   M   30  175.33897
# 40          16             Juhamatti Tapio Aaltonen   M   28  184.00000
# 41          17              Paavo Johannes Aaltonen   M   28  175.00000
# ...        ...                                  ...  ..  ...        ...
# 271078  135553  Galina Ivanovna Zybina (-Fyodorova)   F   25  168.00000
# 271080  135553  Galina Ivanovna Zybina (-Fyodorova)   F   33  168.00000
# 271082  135554                         Bogusaw Zych   M   28  182.00000
# 271102  135563            Olesya Nikolayevna Zykina   F   19  171.00000
# 271103  135563            Olesya Nikolayevna Zykina   F   23  171.00000
#
#            Weight            Team  NOC        Games  Year  Season       City  \
# ...

# %%
Data1 =data2.groupby(['Team','Year'])['Medal'].count().reset_index()

# %%
Data1
# Out:
#                        Team  Year  Medal
# 0     A North American Team  1900      4
# 1               Afghanistan  2008      1
# 2               Afghanistan  2012      1
# 3                   Algeria  1984      2
# 4                   Algeria  1992      2
# ...                     ...   ...    ...
# 2007                 Zambia  1996      1
# 2008               Zimbabwe  1980     15
# 2009               Zimbabwe  2004      3
# 2010               Zimbabwe  2008      4
# 2011                    Zut  1908      3
#
# [2012 rows x 3 columns]

# %%
data4 = Data1.sort_values(by = "Medal",ascending=False).head(10)

# %%
data4.sort_values(by = "Year")
# Out:
#                Team  Year  Medal
# 1611   Soviet Union  1976    336
# 1612   Soviet Union  1980    488
# 512    East Germany  1980    287
# 1874  United States  1984    359
# 1614   Soviet Union  1988    352
# 1847   Unified Team  1992    271
# 1878  United States  1996    255
# 1882  United States  2004    259
# 1884  United States  2008    309
# 1888  United States  2016    256

# %% [markdown]
# # Which sport is having most number of Gold Medals so far? (Top 5)

# %%
df["Medal"].value_counts()
# Out:
# None      231333
# Gold       13372
# Bronze     13295
# Silver     13116
# Name: Medal, dtype: int64

# %%
Most_number_medal = df[["Sport","Medal"]]
Most_number_medal = Most_number_medal.value_counts("Sport").reset_index(name="Counts_of_Medals")[:5]
print(f"SPORTS HAVING MOST NUMBER OF MEDALS:\n")
Most_number_medal
# Out:
# SPORTS HAVING MOST NUMBER OF MEDALS:
#         Sport  Counts_of_Medals
# 0   Athletics             38624
# 1  Gymnastics             26707
# 2    Swimming             23195
# 3    Shooting             11448
# 4     Cycling             10859

# %%
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 10)

plt.title("Sport with the Maximum Medals")
barplot = sns.barplot(data=Most_number_medal, x="Sport", y="Counts_of_Medals", hue="Sport", palette="CMRmap", dodge=False)
barplot.set_xticklabels(rotation=50, labels=Most_number_medal.Sport)
plt.ylabel("Counts_of_Medals")
for bars in barplot.containers:
    barplot.bar_label(bars)
plt.show()

# %% [markdown]
# # Which player has won most number of medals? (Top 5)

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal', 'region',
#        'Age_Level'],
#       dtype='object')

# %%
Individual_medal = df[["Name","Medal"]]
Individual_medal['Name'].unique()
Individual_medal = Individual_medal.value_counts("Name").reset_index(name="Counts_of_Medals")[:5]
print(f"PLAYERS WHO WON MOST NUMBER OF MEDALS:\n")
Individual_medal
# Out:
# PLAYERS WHO WON MOST NUMBER OF MEDALS:
#                        Name  Counts_of_Medals
# 0      Robert Tait McKenzie                58
# 1  Heikki Ilmari Savolainen                39
# 2     Joseph "Josy" Stoffel                38
# 3       Ioannis Theofilakis                36
# 4               Takashi Ono                33

# %%
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 10)

plt.title("athelete name with the Maximum Medals")
barplot = sns.barplot(data=Individual_medal, x="Name", y="Counts_of_Medals", hue="Name", palette="CMRmap", dodge=False)
barplot.set_xticklabels(rotation=50, labels=Most_number_medal.Sport)
plt.ylabel("Counts_of_Medals")
for bars in barplot.containers:
    barplot.bar_label(bars,fontsize = 20)
plt.show()

# %% [markdown]
# # Which player has won most number Gold Medals of medals? (Top 5)

# %%
Gold_medal = df[(df["Medal"] == "Gold")][["Name", "Medal"]]

# %%
Gold_medal.head()
# Out:
#                        Name Medal
# 3      Edgar Lindenau Aabye  Gold
# 42  Paavo Johannes Aaltonen  Gold
# 44  Paavo Johannes Aaltonen  Gold
# 48  Paavo Johannes Aaltonen  Gold
# 60       Kjetil Andr Aamodt  Gold

# %%
Gold_medal = Gold_medal.value_counts(["Name"]).reset_index(name = "Counts_of_Gold_Medal")[:5]

# %%
Gold_medal
# Out:
#                                  Name  Counts_of_Gold_Medal
# 0             Michael Fred Phelps, II                    23
# 1         Raymond Clarence "Ray" Ewry                    10
# 2                Paavo Johannes Nurmi                     9
# 3  Larysa Semenivna Latynina (Diriy-)                     9
# 4                   Mark Andrew Spitz                     9

# %%
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 10)

plt.title("Players with the Maximum Gold Medals")
barplot = sns.barplot(data=Gold_medal, x="Name", y="Counts_of_Gold_Medal", hue="Name", palette="CMRmap", dodge=False)
barplot.set_xticklabels(rotation=50, labels=Gold_medal.Name, fontsize = 15)
plt.ylabel("Counts_of_Gold_Medal")
for bars in barplot.containers:
    barplot.bar_label(bars,fontsize = 20)
plt.show()

# %% [markdown]
# # In which year India won first Gold Medal in Summer Olympics?

# %%
gold_dataset= df[(df["Medal"]=="Gold") & (df["Team"]=="India") & (df["Season"]=="Summer")][["Year","Team","Sport"]]
gold_dataset
# Out:
#         Year   Team   Sport
# 4732    1928  India  Hockey
# 4736    1964  India  Hockey
# 5032    1928  India  Hockey
# 5033    1932  India  Hockey
# 5034    1936  India  Hockey
# ...      ...    ...     ...
# 233749  1980  India  Hockey
# 236445  1932  India  Hockey
# 236446  1936  India  Hockey
# 250689  1948  India  Hockey
# 266934  1928  India  Hockey
#
# [131 rows x 3 columns]

# %%
India_goldmedals=gold_dataset.sort_values(by="Year", ascending=True)
print(f"INDIA WON FIRST GOLD MEDAL IN SUMMER OLYMPICS:\n")
India_goldmedals.head(1)
# Out:
# INDIA WON FIRST GOLD MEDAL IN SUMMER OLYMPICS:
#       Year   Team   Sport
# 4732  1928  India  Hockey

# %% [markdown]
# # In which year India won first Gold Medal in winter Olympics?

# %%
gold_dataset= df[(df["Medal"]=="Gold") & (df["Team"]=="India") & (df["Season"]=="Winter")][["Year","Team","Sport"]]
gold_dataset.head()
# Out:
#         Year   Team     Sport
# 218235  1924  India  Alpinism
# 218239  1924  India  Alpinism
# 218240  1924  India  Alpinism
# 218241  1924  India  Alpinism
# 218242  1924  India  Alpinism

# %%
India_goldmedals=gold_dataset.sort_values(by="Year", ascending=True)
print(f"INDIA WON FIRST GOLD MEDAL IN SUMMER OLYMPICS:\n")
India_goldmedals.head(1)
# Out:
# INDIA WON FIRST GOLD MEDAL IN SUMMER OLYMPICS:
#         Year   Team     Sport
# 218235  1924  India  Alpinism

# %% [markdown]
# # find total number of medal per sport by india

# %%
gold_dataset
# Out:
#         Year   Team     Sport
# 218235  1924  India  Alpinism
# 218239  1924  India  Alpinism
# 218240  1924  India  Alpinism
# 218241  1924  India  Alpinism
# 218242  1924  India  Alpinism
# 218243  1924  India  Alpinism
# 218244  1924  India  Alpinism

# %%
total_number_of_medal = df[(df["Team"]=="India") & (df["Medal"]!="None")]

# %%
total_number_of_medal.head(1)
# Out:
#         ID         Name Sex  Age     Height     Weight   Team  NOC  \
# 4732  2699  Shaukat Ali   M   30  175.33897  70.702393  India  IND
#
#             Games  Year  Season       City   Sport                Event Medal  \
# 4732  1928 Summer  1928  Summer  Amsterdam  Hockey  Hockey Men's Hockey  Gold
#
#      region Age_Level
# 4732  India       Old

# %%
total_number_of_medal_sport = total_number_of_medal.value_counts("Sport").reset_index(name = "Counts_of_Medal")[:10]

# %%
total_number_of_medal_sport
# Out:
#            Sport  Counts_of_Medal
# 0         Hockey              173
# 1       Alpinism                7
# 2      Wrestling                5
# 3       Shooting                4
# 4      Athletics                2
# 5      Badminton                2
# 6         Boxing                2
# 7         Tennis                1
# 8  Weightlifting                1

# %%
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 10)

plt.title("Total Medals won by India")
barplot = sns.barplot(data=total_number_of_medal_sport, y="Sport", x="Counts_of_Medal", hue="Sport", palette="CMRmap", dodge=False)
barplot.set_xticklabels(rotation=0, labels=total_number_of_medal_sport.Sport,fontsize = 15)
plt.xlabel("Counts_of_Medal")
for bars in barplot.containers:
    barplot.bar_label(bars,fontsize = 20)
plt.show()

# %%
total_number_of_medal = df[(df["Team"]=="India") & (df["Medal"]=="Gold")]
total_number_of_medal_sport = total_number_of_medal.value_counts("Sport").reset_index(name = "Counts_of_Medal")[:10]
total_number_of_medal_sport
# Out:
#       Sport  Counts_of_Medal
# 0    Hockey              130
# 1  Alpinism                7
# 2  Shooting                1

# %% [markdown]
# # Which event is most popular in terms on number of players? (Top 5)

# %%
Number_of_players = df[["Event","Name"]]
Number_of_players = Number_of_players.value_counts("Event").reset_index(name="No_of_players")[:5]
print(f"MOST POPULAR EVENT IN TERMS ON NUMBER OF PLAYERS:\n")
Number_of_players
# Out:
# MOST POPULAR EVENT IN TERMS ON NUMBER OF PLAYERS:
#                          Event  No_of_players
# 0      Football Men's Football           5733
# 1  Ice Hockey Men's Ice Hockey           4762
# 2          Hockey Men's Hockey           3958
# 3  Water Polo Men's Water Polo           3358
# 4  Basketball Men's Basketball           3280

# %%
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 10)

plt.title("Most Popular Events in terms of No of Players")
barplot = sns.barplot(data=Number_of_players, x="Event", y="No_of_players", hue="Event", palette="CMRmap", dodge=False)
barplot.set_xticklabels(rotation=50, labels=Number_of_players.Event)
plt.ylabel("No_of_players")
for bars in barplot.containers:
    barplot.bar_label(bars,fontsize = 20)
plt.show()

# %% [markdown]
# # Which sport is having most female Gold Medalists? (Top 5)

# %%
Female_gold_medalists = df[(df["Medal"] == "Gold") & (df["Sex"] == "F")][["Sport", "Medal"]]
Female_gold_medalists = Female_gold_medalists.value_counts(["Sport"]).reset_index(name = "Female_gold_medalists")[:5]
print(f"\nFEMALE GOLD MEDALISTS IN SUMMER OLYMPICS:\n")
Female_gold_medalists
# Out:
# FEMALE GOLD MEDALISTS IN SUMMER OLYMPICS:
#         Sport  Female_gold_medalists
# 0    Swimming                    493
# 1   Athletics                    428
# 2      Rowing                    238
# 3  Gymnastics                    234
# 4      Hockey                    158

# %%
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 10)

plt.title("Female Gold Medalists in Summer Olympics")
barplot = sns.barplot(data=Female_gold_medalists, x="Sport", y="Female_gold_medalists", hue="Sport", palette="CMRmap", dodge=False)
barplot.set_xticklabels(rotation=50, labels=Female_gold_medalists.Sport)
plt.ylabel("Female_gold_medalists")
for bars in barplot.containers:
    barplot.bar_label(bars,fontsize = 20)
plt.show()

# %%
Gender_by_Medals = df[df["Medal"]!="None"]

# %%
Gender_by_Medals
# Out:
#             ID                                 Name Sex  Age     Height  \
# 3            4                 Edgar Lindenau Aabye   M   34  175.33897
# 37          15                 Arvo Ossian Aaltonen   M   30  175.33897
# 38          15                 Arvo Ossian Aaltonen   M   30  175.33897
# 40          16             Juhamatti Tapio Aaltonen   M   28  184.00000
# 41          17              Paavo Johannes Aaltonen   M   28  175.00000
# ...        ...                                  ...  ..  ...        ...
# 271078  135553  Galina Ivanovna Zybina (-Fyodorova)   F   25  168.00000
# 271080  135553  Galina Ivanovna Zybina (-Fyodorova)   F   33  168.00000
# 271082  135554                         Bogusaw Zych   M   28  182.00000
# 271102  135563            Olesya Nikolayevna Zykina   F   19  171.00000
# 271103  135563            Olesya Nikolayevna Zykina   F   23  171.00000
#
#            Weight            Team  NOC        Games  Year  Season       City  \
# ...

# %%
Gender_by_Medals = pd.crosstab(Gender_by_Medals["Sex"],Gender_by_Medals["Medal"])
Gender_by_Medals
# Out:
# Medal  Bronze  Gold  Silver
# Sex
# F        3771  3747    3735
# M        9524  9625    9381

# %%
india_by_Medals = df[(df["Team"]=="India") & (df["Medal"]!="None")]
india_by_Medals = pd.crosstab(india_by_Medals["Team"],india_by_Medals["Medal"])
india_by_Medals
# Out:
# Medal  Bronze  Gold  Silver
# Team
# India      40   138      19

# %% [markdown]
# # sport wise with maximum medals

# %%
test1=df.groupby(['Team','Year'])['Medal'].count().reset_index()

# %%
test1.sort_values(by = "Medal",ascending=False)
# Out:
#                  Team  Year  Medal
# 4841    United States  1992    936
# 4840    United States  1988    886
# 4803     Unified Team  1992    832
# 4843    United States  1996    827
# 4821    United States  1904    823
# ...               ...   ...    ...
# 3640     Pirouette-31  1900      1
# 1682            Gabon  1972      1
# 4159      Solos Carex  2008      1
# 3644   Plume-patte-32  1900      1
# 3609  Pettit-Poucet-6  1900      1
#
# [5170 rows x 3 columns]

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal', 'region',
#        'Age_Level'],
#       dtype='object')

# %%
df2 = df[df["Medal"]!="None"]

# %%
df3 = df2.groupby(['Sport','Medal'])[['Medal']].value_counts().sort_values(ascending=False).reset_index(name = "No of medal")[:15]

# %%
df3
# Out:
#          Sport   Medal  No of medal
# 0    Athletics    Gold         1339
# 1    Athletics  Silver         1334
# 2    Athletics  Bronze         1296
# 3     Swimming    Gold         1099
# 4     Swimming  Silver          993
# 5       Rowing  Bronze          990
# 6       Rowing    Gold          978
# 7       Rowing  Silver          977
# 8     Swimming  Bronze          956
# 9   Gymnastics    Gold          791
# 10  Gymnastics  Silver          746
# 11  Gymnastics  Bronze          719
# 12     Fencing    Gold          594
# 13     Fencing  Silver          583
# 14     Fencing  Bronze          566

# %%
plt.figure(figsize=(15,10))
sns.set_theme(style="darkgrid")
barplot = sns.barplot(x = "Sport",y = "No of medal", hue=df3["Medal"], data = df3 )
for bars in barplot.containers:
    barplot.bar_label(bars,fontsize = 20)
plt.title("sport wise No of medal in Summer Olympics")
plt.show()

# %% [markdown]
# # What is the number of Sports held per year in Summer Olypics, since 1896?

# %%
data3 = df[(df["Season"]=="Summer") & (df["Medal"]!="None")]
data3
# Out:
#             ID                                 Name Sex  Age     Height  \
# 3            4                 Edgar Lindenau Aabye   M   34  175.33897
# 37          15                 Arvo Ossian Aaltonen   M   30  175.33897
# 38          15                 Arvo Ossian Aaltonen   M   30  175.33897
# 41          17              Paavo Johannes Aaltonen   M   28  175.00000
# 42          17              Paavo Johannes Aaltonen   M   28  175.00000
# ...        ...                                  ...  ..  ...        ...
# 271078  135553  Galina Ivanovna Zybina (-Fyodorova)   F   25  168.00000
# 271080  135553  Galina Ivanovna Zybina (-Fyodorova)   F   33  168.00000
# 271082  135554                         Bogusaw Zych   M   28  182.00000
# 271102  135563            Olesya Nikolayevna Zykina   F   19  171.00000
# 271103  135563            Olesya Nikolayevna Zykina   F   23  171.00000
#
#            Weight            Team  NOC        Games  Year  Season       City  \
# ...

# %%
df_sports = df.groupby("Year")["Sport"].nunique().sort_values(ascending=False).reset_index()

# %%
df_sports
# Out:
#     Year  Sport
# 0   1992     41
# 1   1988     37
# 2   1984     35
# 3   2016     34
# 4   2008     34
# 5   2004     34
# 6   2000     34
# 7   1976     33
# 8   1980     33
# 9   1972     33
# 10  1936     32
# 11  2012     32
# 12  1964     31
# 13  1996     31
# 14  1968     30
# 15  1924     30
# 16  1948     29
# 17  1952     27
# 18  1956     27
# 19  1960     27
# 20  1932     25
# 21  1928     25
# 22  1920     25
# 23  1908     24
# 24  1900     20
# 25  1904     18
# 26  1912     17
# 27  2002     15
# 28  2006     15
# 29  2010     15
# 30  2014     15
# 31  1998     14
# 32  1906     13
# 33  1994     12
# 34  1896      9

# %%
fig = plt.figure(figsize=(30,15))
barplot = sns.barplot(x = "Year", y = "Sport", data=df_sports, palette="summer", saturation=.65 )
plt.xlabel("Year", fontsize = 30)
plt.ylabel("Sport", fontsize = 30)
for bars in barplot.containers:
    barplot.bar_label(bars,fontsize = 25)
plt.xticks(fontsize = 20)
plt.show()

# %% [markdown]
# # How many cities hosted the Summer Olympics games, since 1896?

# %%
df_medal_holders = df[(df.Medal !='None') & (df.Season == 'Summer')]

df_medal_holders_above50 = df_medal_holders[df.Age >= 50]

df_medal_holders_above50.head(10)
# Out:
#           ID                        Name Sex  Age     Height     Weight  \
# 3680    2112         Abdullah Al-Rashidi   M   52  183.00000  83.000000
# 5077    2894      Derek Swithin Allhusen   M   54  180.00000  71.000000
# 5078    2894      Derek Swithin Allhusen   M   54  180.00000  71.000000
# 7961    4404          Johan August Anker   M   56  175.33897  70.702393
# 13393   7272  Nikolaus "Klaus" Balkenhol   M   52  178.00000  83.000000
# 13394   7272  Nikolaus "Klaus" Balkenhol   M   52  178.00000  83.000000
# 13396   7272  Nikolaus "Klaus" Balkenhol   M   56  178.00000  83.000000
# 14364   7744           Ernest Barberolle   M   58  156.00000  56.000000
# 17552   9349             Ludger Beerbaum   M   52  190.00000  85.000000
# 21999  11599        Rudolf Georg Binding   M   60  175.33897  70.702393
#
#                               Team  NOC        Games  Year  Season  \
# 3680   Individual Olympic Athletes  IOA  2016 Summer  2016  Summer
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal', 'region',
#        'Age_Level'],
#       dtype='object')

# %%
data4 = df[df["Season"]=="Summer"]

# %%
data4
# Out:
#             ID                                Name Sex  Age     Height  \
# 0            1                           A Dijiang   M   24  180.00000
# 1            2                            A Lamusi   M   23  170.00000
# 2            3                 Gunnar Nielsen Aaby   M   24  175.33897
# 3            4                Edgar Lindenau Aabye   M   34  175.33897
# 26           8  Cornelia "Cor" Aalten (-Strannood)   F   18  168.00000
# ...        ...                                 ...  ..  ...        ...
# 271106  135565            Fernando scar Zylberberg   M   27  168.00000
# 271107  135566          James Francis "Jim" Zylker   M   21  175.00000
# 271108  135567        Aleksandr Viktorovich Zyuzin   M   24  183.00000
# 271109  135567        Aleksandr Viktorovich Zyuzin   M   28  183.00000
# 271110  135568              Olga Igorevna Zyuzkova   F   33  171.00000
#
#            Weight            Team  NOC        Games  Year  Season  \
# ...

# %%
data5 = data4["City"].nunique()

# %%
data5
# Out:
# 23

# %% [markdown]
# # How many cities in which Olympics was conducted more than once?

# %%
data4.groupby(["City"])["Year"].nunique().sort_values(ascending=False).reset_index(name = "Conduct no of year")
# Out:
#               City  Conduct no of year
# 0           Athina                   3
# 1           London                   3
# 2        Stockholm                   2
# 3      Los Angeles                   2
# 4            Paris                   2
# 5        Amsterdam                   1
# 6           Moskva                   1
# 7           Sydney                   1
# 8        St. Louis                   1
# 9            Seoul                   1
# 10            Roma                   1
# 11  Rio de Janeiro                   1
# 12          Munich                   1
# 13     Mexico City                   1
# 14        Montreal                   1
# 15       Antwerpen                   1
# 16       Melbourne                   1
# 17        Helsinki                   1
# 18          Berlin                   1
# 19         Beijing                   1
# 20       Barcelona                   1
# 21         Atlanta                   1
# 22           Tokyo                   1

# %% [markdown]
# # How many cities hosted the winter Olympics games, since 1896?

# %%
data6 = df[df["Season"]=="Winter"]

# %%
data6
# Out:
#             ID                      Name Sex  Age  Height  Weight  \
# 4            5  Christine Jacoba Aaftink   F   21   185.0    82.0
# 5            5  Christine Jacoba Aaftink   F   21   185.0    82.0
# 6            5  Christine Jacoba Aaftink   F   25   185.0    82.0
# 7            5  Christine Jacoba Aaftink   F   25   185.0    82.0
# 8            5  Christine Jacoba Aaftink   F   27   185.0    82.0
# ...        ...                       ...  ..  ...     ...     ...
# 271111  135569                Andrzej ya   M   29   179.0    89.0
# 271112  135570                  Piotr ya   M   27   176.0    59.0
# 271113  135570                  Piotr ya   M   27   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M   30   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M   34   185.0    96.0
#
#                Team  NOC        Games  Year  Season            City  \
# 4       Netherlands  NED  1988 Winter  1988  Winter         Calgary
# ...

# %%
data7 = data6["City"].nunique()

# %%
data7
# Out:
# 19

# %% [markdown]
# # How many cities in which Olympics was conducted more than once?

# %%
data6.groupby(["City"])["Year"].nunique().sort_values(ascending=False).reset_index(name = "Conduct no of year")
# Out:
#                       City  Conduct no of year
# 0                Innsbruck                   2
# 1              Lake Placid                   2
# 2             Sankt Moritz                   2
# 3              Albertville                   1
# 4           Salt Lake City                   1
# 5                   Torino                   1
# 6             Squaw Valley                   1
# 7                    Sochi                   1
# 8                 Sarajevo                   1
# 9                  Sapporo                   1
# 10                  Nagano                   1
# 11                    Oslo                   1
# 12                 Calgary                   1
# 13             Lillehammer                   1
# 14                Grenoble                   1
# 15  Garmisch-Partenkirchen                   1
# 16       Cortina d'Ampezzo                   1
# 17                Chamonix                   1
# 18               Vancouver                   1

# %% [markdown]
# # How many medals were won by women in Summer Olympics?

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal', 'region',
#        'Age_Level'],
#       dtype='object')

# %%
Dt = df[(df["Sex"]=="F") & (df["Season"]=="Summer") & (df["Medal"]!="None")]

# %%
Dt
# Out:
#             ID                                     Name Sex  Age     Height  \
# 79          21                Ragnhild Margrethe Aamodt   F   27  163.00000
# 91          29                     Willemien Aardenburg   F   22  175.33897
# 105         37                       Ann Kristin Aarnes   F   23  182.00000
# 161         65                        Patimat Abakarova   F   21  165.00000
# 163         67  Mariya Vasilyevna Abakumova (-Tarabina)   F   22  179.00000
# ...        ...                                      ...  ..  ...        ...
# 271076  135553      Galina Ivanovna Zybina (-Fyodorova)   F   21  168.00000
# 271078  135553      Galina Ivanovna Zybina (-Fyodorova)   F   25  168.00000
# 271080  135553      Galina Ivanovna Zybina (-Fyodorova)   F   33  168.00000
# 271102  135563                Olesya Nikolayevna Zykina   F   19  171.00000
# 271103  135563                Olesya Nikolayevna Zykina   F   23  171.00000
#
# ...

# %%
Dt1 = Dt.value_counts("Medal")

# %%
Dt1
# Out:
# Medal
# Bronze    3174
# Gold      3140
# Silver    3128
# dtype: int64

# %% [markdown]
# # How many medals were won by women in winter Olympics?

# %%
Dt = df[(df["Sex"]=="F") & (df["Season"]=="Winter") & (df["Medal"]!="None")]

# %%
Dt
# Out:
#             ID                                 Name Sex  Age  Height  Weight  \
# 974        548   Yekaterina Konstantinovna Abramova   F   23   167.0    65.0
# 1210       680             Rita Nikolayevna Achkina   F   30   168.0    63.0
# 1519       840               Victoria "Vicki" Adams   F   24   164.0    69.0
# 2126      1181  Meghan Christina Agosta (-Marciano)   F   18   168.0    67.0
# 2127      1181  Meghan Christina Agosta (-Marciano)   F   23   168.0    67.0
# ...        ...                                  ...  ..  ...     ...     ...
# 269977  135066                           Katia Zini   F   24   164.0    57.0
# 269984  135067                            Mara Zini   F   26   169.0    53.0
# 270174  135163                      Luiza Zotkowska   F   23   160.0    52.0
# 270178  135163                      Luiza Zotkowska   F   27   160.0    52.0
# 270480  135290              Vera Zozua (-Pyatnizin)   F   24   157.0    69.0
#
# ...

# %%
Dt1 = Dt.value_counts("Medal")

# %%
Dt1
# Out:
# Medal
# Gold      607
# Silver    607
# Bronze    597
# dtype: int64

# %% [markdown]
# # Top 10 Women Athletes - Gold Medals

# %%
data7 = df[(df["Sex"]=="F") & (df["Medal"]=="Gold")]

# %%
data7
# Out:
#             ID                                       Name Sex  Age     Height  \
# 79          21                  Ragnhild Margrethe Aamodt   F   27  163.00000
# 283        150              Margaret Ives Abbott (-Dunne)   F   23  175.33897
# 1494       832                      Nicola Virginia Adams   F   29  164.00000
# 1495       832                      Nicola Virginia Adams   F   33  164.00000
# 1527       846       Valerie Kasanita Adams-Vili (-Price)   F   23  193.00000
# ...        ...                                        ...  ..  ...        ...
# 270588  135331                 Olha Valentynivna Zubareva   F   22  182.00000
# 270934  135488               Nataliya Vladimirovna Zuyeva   F   19  176.00000
# 270970  135501  Ellina Aleksandrovna Zvereva (Kisheyeva-)   F   39  183.00000
# 271009  135520                                Julia Zwehl   F   28  167.00000
# 271076  135553        Galina Ivanovna Zybina (-Fyodorova)   F   21  168.00000
#
# ...

# %%
data8 = data7.groupby(['Name'])['Medal'].count().sort_values(ascending=False).reset_index()[:10]

# %%
data8
# Out:
#                                               Name  Medal
# 0               Larysa Semenivna Latynina (Diriy-)      9
# 1                           Birgit Fischer-Schmidt      8
# 2  Jennifer Elisabeth "Jenny" Thompson (-Cumpelik)      8
# 3                           Vra slavsk (-Odloilov)      7
# 4                          Maria Valentina Vezzali      6
# 5                   Amy Deloris Van Dyken (-Rouen)      6
# 6          Lidiya Pavlovna Skoblikova (-Polozkova)      6
# 7                                     Kristin Otto      6
# 8                            Isabelle Regina Werth      6
# 9                           Allyson Michelle Felix      6

# %%
plt.figure(figsize=(19,12))
barplot = sns.barplot(x = "Name",y = "Medal", data = data8 )
plt.xticks(rotation=75,fontsize=20)
for bars in barplot.containers:
    barplot.bar_label(bars,fontsize = 20)
plt.title(" top 10 gold medelist woman")
plt.show()

# %% [markdown]
# # Top 10 Women Athletes - Total Medals

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal', 'region',
#        'Age_Level'],
#       dtype='object')

# %%
data9 = df[(df["Sex"]=="F") & (df["Medal"]!="None")]

# %%
data9
# Out:
#             ID                                     Name Sex  Age     Height  \
# 79          21                Ragnhild Margrethe Aamodt   F   27  163.00000
# 91          29                     Willemien Aardenburg   F   22  175.33897
# 105         37                       Ann Kristin Aarnes   F   23  182.00000
# 161         65                        Patimat Abakarova   F   21  165.00000
# 163         67  Mariya Vasilyevna Abakumova (-Tarabina)   F   22  179.00000
# ...        ...                                      ...  ..  ...        ...
# 271076  135553      Galina Ivanovna Zybina (-Fyodorova)   F   21  168.00000
# 271078  135553      Galina Ivanovna Zybina (-Fyodorova)   F   25  168.00000
# 271080  135553      Galina Ivanovna Zybina (-Fyodorova)   F   33  168.00000
# 271102  135563                Olesya Nikolayevna Zykina   F   19  171.00000
# 271103  135563                Olesya Nikolayevna Zykina   F   23  171.00000
#
# ...

# %%
data10 = data9.groupby(["Name"])["Medal"].count().reset_index()

# %%
data11 = data10.sort_values(by = "Medal", ascending=False)[:10]

# %%
data11
# Out:
#                                                  Name  Medal
# 3672               Larysa Semenivna Latynina (Diriy-)     18
# 2896  Jennifer Elisabeth "Jenny" Thompson (-Cumpelik)     12
# 5054                    Natalie Anne Coughlin (-Hall)     12
# 1393             Dara Grace Torres (-Hoffman, -Minas)     12
# 772                            Birgit Fischer-Schmidt     12
# 6893                           Vra slavsk (-Odloilov)     11
# 2001                            Franziska van Almsick     10
# 5636                         Raisa Petrovna Smetanina     10
# 6218                                Stefania Belmondo     10
# 2726                            Isabelle Regina Werth     10

# %% [markdown]
# # How many athlete participated in each sport in Summer Olympics?

# %%
dff1 = df[df["Season"]=="Summer"].groupby("Sport")["Name"].nunique().reset_index(name = "No of athlete per game").sort_values(by = "No of athlete per game",  
                                                                                                                    ascending=False)

# %%
dff1
# Out:
#                     Sport  No of athlete per game
# 4               Athletics                   22053
# 40               Swimming                    8761
# 34                 Rowing                    7684
# 19               Football                    6161
# 14                Cycling                    5819
# 10                 Boxing                    5254
# 51              Wrestling                    4987
# 38               Shooting                    4879
# 37                Sailing                    4480
# 21             Gymnastics                    4132
# 17                Fencing                    4118
# 23                 Hockey                    3813
# 7              Basketball                    3412
# 11               Canoeing                    3204
# 50          Weightlifting                    2880
# 26                   Judo                    2721
# 22               Handball                    2699
# 49             Water Polo                    2599
# ...

# %%
plt.figure(figsize=(28,17))
barplot = sns.barplot(x = "Sport",y = "No of athlete per game", data = dff1 )
plt.xticks(rotation=90,fontsize=20)
for bars in barplot.containers:
    barplot.bar_label(bars,fontsize = 20)
plt.title(" No of athlete per game")
plt.show()

# %%
df[df["Season"]=="Summer"].groupby(["Year","Sport"])["Name"].count().reset_index(name = "No of athlete per game").sort_values(by = "No of athlete per game",  
                                                                                                                    ascending=False)[:10]
# Out:
#      Year       Sport  No of athlete per game
# 639  2016   Athletics                    2508
# 505  2000   Athletics                    2468
# 234  1952  Gymnastics                    2391
# 474  1996   Athletics                    2386
# 607  2012   Athletics                    2278
# 573  2008   Athletics                    2244
# 539  2004   Athletics                    2175
# 418  1988   Athletics                    2062
# 445  1992   Athletics                    2054
# 595  2008    Swimming                    1749

# %% [markdown]
# # Top 5 countries to win most Gold medals across all seasons collectively and particular country USA

# %%
data11 = df[(df['Medal'] == 'Gold')][['Team']].value_counts().reset_index(name='no of gold Medal').rename(columns = {"index":"Team"})[:5]

# %%
data11
# Out:
#             Team  no of gold Medal
# 0  United States              2474
# 1   Soviet Union              1058
# 2        Germany               679
# 3          Italy               535
# 4  Great Britain               519

# %%
g = sns.barplot(x="Team", y="no of gold Medal", data=data11,
                palette="muted")
plt.xlabel("Top 5 countries")
plt.ylabel("Number of Medals")
for bars in g.containers:
    g.bar_label(bars,fontsize = 20)
plt.title('Medals per Country')
# Out:
# Text(0.5, 1.0, 'Medals per Country')

# %%
data12 = df[(df['Medal'] == 'Gold')][['Team',"Year"]].value_counts().reset_index(name='no of gold Medal').rename(columns = {"index":"Team"})

# %%
data12
# Out:
#                Team  Year  no of gold Medal
# 0      Soviet Union  1980               201
# 1     United States  1984               190
# 2      Soviet Union  1988               168
# 3     United States  1996               157
# 4      Soviet Union  1976               148
# ...             ...   ...               ...
# 1189         Jordan  2016                 1
# 1190          Japan  2014                 1
# 1191          Japan  2006                 1
# 1192          Japan  1952                 1
# 1193       Zimbabwe  2008                 1
#
# [1194 rows x 3 columns]

# %%
data12[data12["Team"]=="United States"]
# Out:
#               Team  Year  no of gold Medal
# 1    United States  1984               190
# 3    United States  1996               157
# 6    United States  2012               139
# 7    United States  2016               137
# 8    United States  2000               128
# 11   United States  2008               121
# 12   United States  2004               115
# 13   United States  1920               111
# 15   United States  1968               100
# 16   United States  1960                97
# 17   United States  1964                96
# 22   United States  1992                92
# 23   United States  1924                92
# 25   United States  1988                89
# 28   United States  1948                82
# 29   United States  1952                77
# 30   United States  1976                73
# 32   United States  1972                72
# 33   United States  1932                71
# 38   United States  1904                65
# 41   United States  1956                61
# ...

# %%
data12[data12["Team"]=="India"]
# Out:
#        Team  Year  no of gold Medal
# 162   India  1948                20
# 175   India  1936                19
# 193   India  1956                17
# 210   India  1980                16
# 217   India  1964                15
# 229   India  1932                15
# 249   India  1928                14
# 253   India  1952                14
# 398   India  1924                 7
# 1161  India  2008                 1

# %% [markdown]
# # Top 5 countries to win most Gold medals in 2012

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal', 'region',
#        'Age_Level'],
#       dtype='object')

# %%
data13 = df[(df["Medal"]=="Gold") & (df["Year"]==2012)]["Team"].value_counts().reset_index(name = "No of gold medal")[:5]
data13
# Out:
#            index  No of gold medal
# 0  United States               139
# 1         Russia                50
# 2          China                50
# 3  Great Britain                46
# 4        Germany                43

# %%
g = sns.barplot(x="index", y="No of gold medal", data=data13,
                 palette="muted")
plt.xlabel("Top 5 countries")
plt.ylabel("Number of Medals")
for bars in g.containers:
    g.bar_label(bars,fontsize = 20)
plt.title('Medals per Country in 2012')
# Out:
# Text(0.5, 1.0, 'Medals per Country in 2012')

# %% [markdown]
# # event with the greatest number of Gold Medals

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal', 'region',
#        'Age_Level'],
#       dtype='object')

# %%
data14 = df[df["Medal"]=="Gold"]

# %%
data14
# Out:
#             ID                                 Name Sex  Age     Height  \
# 3            4                 Edgar Lindenau Aabye   M   34  175.33897
# 42          17              Paavo Johannes Aaltonen   M   28  175.00000
# 44          17              Paavo Johannes Aaltonen   M   28  175.00000
# 48          17              Paavo Johannes Aaltonen   M   28  175.00000
# 60          20                   Kjetil Andr Aamodt   M   20  176.00000
# ...        ...                                  ...  ..  ...        ...
# 270981  135503                      Zurab Zviadauri   M   23  182.00000
# 271009  135520                          Julia Zwehl   F   28  167.00000
# 271016  135523       Ronald Ferdinand "Ron" Zwerver   M   29  200.00000
# 271049  135545                      Henk Jan Zwolle   M   31  197.00000
# 271076  135553  Galina Ivanovna Zybina (-Fyodorova)   F   21  168.00000
#
#            Weight            Team  NOC        Games  Year  Season  \
# ...

# %%
data15 = data14.groupby("Event")["Medal"].count().reset_index()

# %%
data16 = data15.sort_values(by = "Medal",ascending=False)[:5]

# %%
data16
# Out:
#                                 Event  Medal
# 336           Football Men's Football    414
# 382       Ice Hockey Men's Ice Hockey    407
# 380               Hockey Men's Hockey    360
# 698       Water Polo Men's Water Polo    287
# 367  Gymnastics Men's Team All-Around    249

# %%
barplot = sns.barplot(x="Event", y="Medal", data=data16,
          palette="muted")
plt.xlabel("Event")
plt.ylabel("Number of Gold Medals")
plt.xticks(rotation=90,fontsize=20)
for bars in barplot.containers:
    barplot.bar_label(bars,fontsize = 20)
plt.title('no of gold medal by event')
# Out:
# Text(0.5, 1.0, 'no of gold medal by event')

# %% [markdown]
# # How many athlete participate in each Summer Olympic?

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal', 'region',
#        'Age_Level'],
#       dtype='object')

# %%
data17 = df.groupby("Year")["Name"].count().reset_index(name = "No of athlete per year")

# %%
data17
# Out:
#     Year  No of athlete per year
# 0   1896                     380
# 1   1900                    1936
# 2   1904                    1301
# 3   1906                    1733
# 4   1908                    3101
# 5   1912                    4040
# 6   1920                    4292
# 7   1924                    5693
# 8   1928                    5574
# 9   1932                    3321
# 10  1936                    7401
# 11  1948                    7480
# 12  1952                    9358
# 13  1956                    6434
# 14  1960                    9235
# 15  1964                    9480
# 16  1968                   10479
# 17  1972                   11959
# 18  1976                   10502
# 19  1980                    8937
# 20  1984                   11588
# 21  1988                   14676
# 22  1992                   16413
# 23  1994                    3160
# 24  1996                   13780
# 25  1998                    3605
# 26  2000                   13821
# ...

# %%
fig = plt.figure(figsize=(30,15))
barplot = sns.barplot(x = "Year", y = "No of athlete per year", data=data17, palette="summer", saturation=.65 )
plt.xlabel("Year", fontsize = 30)
plt.ylabel("No of athlete per year", fontsize = 30)
plt.xticks(fontsize = 20)
for bars in barplot.containers:
    barplot.bar_label(bars,fontsize = 20)
plt.show()

# %% [markdown]
# # Top 10 countries with total medals in Summer Olympic games

# %%
data18 = df[(df["Medal"]!="None") & (df["Season"]=="Summer")][["Team","Medal"]]

# %%
data18
# Out:
#                   Team   Medal
# 3       Denmark/Sweden    Gold
# 37             Finland  Bronze
# 38             Finland  Bronze
# 41             Finland  Bronze
# 42             Finland    Gold
# ...                ...     ...
# 271078    Soviet Union  Silver
# 271080    Soviet Union  Bronze
# 271082          Poland  Bronze
# 271102          Russia  Bronze
# 271103          Russia  Silver
#
# [34088 rows x 2 columns]

# %%
data19 = data18.value_counts("Team").reset_index(name = "No of total medal")[:5]

# %%
data19
# Out:
#             Team  No of total medal
# 0  United States               4686
# 1   Soviet Union               2061
# 2        Germany               1687
# 3  Great Britain               1598
# 4         France               1408

# %%
fig = plt.figure(figsize=(30,15))
barplot = sns.barplot(x = "Team", y = "No of total medal", data=data19, palette="RdYlGn", saturation=.65 )
plt.xlabel("Team", fontsize = 30)
plt.ylabel("No of total medal", fontsize = 30)
plt.xticks(fontsize = 20)
for bars in barplot.containers:
    barplot.bar_label(bars,fontsize = 20)
plt.show()

# %% [markdown]
# # Athletes participation by gender over years for Olympics

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal', 'region',
#        'Age_Level'],
#       dtype='object')

# %%
data20 = df.groupby(["Sex","Year"])["Name"].nunique().reset_index(name = "No of athletes")

# %%
data20
# Out:
#    Sex  Year  No of athletes
# 0    F  1900              23
# 1    F  1904               6
# 2    F  1906               6
# 3    F  1908              44
# 4    F  1912              53
# ..  ..   ...             ...
# 64   M  2008            6284
# 65   M  2010            1503
# 66   M  2012            5858
# 67   M  2014            1642
# 68   M  2016            6143
#
# [69 rows x 3 columns]

# %%
fig = plt.figure(figsize=(18,10))
ax = sns.pointplot(x = data20["Year"] , y = data20["No of athletes"],
                   markers="h" , hue = data20["Sex"],palette = ["r","b"])
plt.grid(True)
plt.xticks(rotation = 60)
plt.ylabel("count")
plt.title("Athletes by gender over years for Summer Olympics",color="b")
# Out:
# Text(0.5, 1.0, 'Athletes by gender over years for Summer Olympics')

# %% [markdown]
# # Great Britain Medals in Sports across Years

# %%
data21 = df[(df['Medal'] != 'None')][['Team',"Year","Sport"]].value_counts().reset_index(name='no of total Medal').rename(columns = {"index":"Team"})

# %%
data21
# Out:
#                Team  Year          Sport  no of total Medal
# 0     United States  1968       Swimming                 83
# 1     United States  1972       Swimming                 74
# 2     United States  2016       Swimming                 71
# 3     United States  2012       Swimming                 68
# 4     United States  2008       Swimming                 68
# ...             ...   ...            ...                ...
# 7291        Finland  2006  Alpine Skiing                  1
# 7292        Romania  2000           Judo                  1
# 7293        Finland  2004      Wrestling                  1
# 7294        Romania  2000       Shooting                  1
# 7295   South Africa  1924         Boxing                  1
#
# [7296 rows x 4 columns]

# %%
data21["Team"].unique()
# Out:
# array(['United States', 'Soviet Union', 'East Germany', 'Australia',
#        'Belgium', 'Denmark', 'Norway', 'Sweden', 'Canada', 'Germany',
#        'Finland', 'Romania', 'Brazil', 'Netherlands', 'Great Britain',
#        'West Germany', 'France', 'Unified Team', 'Jamaica', 'Yugoslavia',
#        'Italy', 'Russia', 'South Korea', 'Cuba', 'Japan',
#        'Czech Republic', 'Spain', 'Serbia', 'China',
#        'Phalainis ton Thorichtou "Hydra"-2',
#        'Marinai della nave da guerra "Varese"', 'Czechoslovakia',
#        'Austria', 'Bulgaria', 'Hungary', 'Chinese Taipei', 'Ghana',
#        'India', 'Switzerland', 'Cameroon', 'Nigeria', 'Argentina',
#        'Minerva Amsterdam', 'Chile',
#        'Union des Socits Franais de Sports Athletiques', 'Uruguay',
#        'Poland', 'Paraguay',
#        'Large boat, Central Naval Prep School "Poros"-1', 'Pakistan',
#        'Mexico', 'Croatia', 'Ukraine', 'Cornwall', 'Frankfurt Club',
# ...

# %%
data22 = data21[data21["Team"]=="Great Britain"][:20]
data22.sort_values(by = "Year")
# Out:
#               Team  Year       Sport  no of total Medal
# 78   Great Britain  1908    Shooting                 33
# 262  Great Britain  1908   Athletics                 21
# 100  Great Britain  1912    Shooting                 31
# 219  Great Britain  1912  Gymnastics                 23
# 231  Great Britain  1912   Athletics                 22
# 152  Great Britain  1920   Athletics                 25
# 232  Great Britain  1924   Athletics                 22
# 366  Great Britain  1964   Athletics                 18
# 518  Great Britain  1980   Athletics                 16
# 235  Great Britain  1984   Athletics                 22
# 525  Great Britain  1988      Hockey                 16
# 393  Great Britain  2000      Rowing                 17
# 326  Great Britain  2008     Cycling                 19
# 217  Great Britain  2008      Rowing                 23
# 321  Great Britain  2012     Cycling                 19
# 118  Great Britain  2012      Rowing                 28
# ...

# %%
data24 = df[(df['Medal'] != 'None')][['Team',"Year"]].value_counts().reset_index(name='no of total Medal').rename(columns = {"index":"Team"})

# %%
data24
# Out:
#                Team  Year  no of total Medal
# 0      Soviet Union  1980                488
# 1     United States  1984                359
# 2      Soviet Union  1988                352
# 3      Soviet Union  1976                336
# 4     United States  2008                309
# ...             ...   ...                ...
# 2007       Portugal  2016                  1
# 2008         Sweden  1900                  1
# 2009         Mexico  1952                  1
# 2010       Mongolia  2004                  1
# 2011          Spain  1952                  1
#
# [2012 rows x 3 columns]

# %%
data25 = data24[data24["Team"]=="Great Britain"][:20]
data25
# Out:
#               Team  Year  no of total Medal
# 35   Great Britain  1908                167
# 46   Great Britain  2016                145
# 54   Great Britain  1912                128
# 56   Great Britain  2012                122
# 74   Great Britain  1920                101
# 92   Great Britain  1924                 82
# 95   Great Britain  2008                 81
# 121  Great Britain  1984                 71
# 163  Great Britain  1948                 61
# 167  Great Britain  1928                 59
# 185  Great Britain  2004                 55
# 191  Great Britain  1988                 54
# 196  Great Britain  2000                 52
# 212  Great Britain  1992                 50
# 224  Great Britain  1980                 48
# 227  Great Britain  1936                 47
# 300  Great Britain  1956                 37
# 330  Great Britain  1932                 33
# 336  Great Britain  1976                 33
# 339  Great Britain  1952                 32

# %%
fig = plt.figure(figsize=(30,15))
barplot = sns.barplot(x = "Year", y = "no of total Medal", data=data25, palette="summer", saturation=.65 )
plt.xlabel("Year", fontsize = 30)
plt.ylabel("no of total Medal", fontsize = 30)
plt.xticks(fontsize = 20)
for bars in barplot.containers:
    barplot.bar_label(bars,fontsize = 20)
plt.title("No of total medal wining per year by UK", fontsize = 35)
plt.show()
